# %%
marks = [1,2,3,4,5]
marks.append(7)
print(marks)
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
subject = ("Maths", "Science", "English")

print(subject[0])
# Out:
# Maths

# %%
hobbies = {"reading", "music", "Sport", "music"}
print (hobbies)
# Out:
# {'reading', 'music', 'Sport'}

# %%
student = {
    "name" : "priya" ,
     "course" : "python" ,
     "year" : "2024"
     }

student[ "age" ]=20
print(student)
# Out:
# {'name': 'priya', 'course': 'python', 'year': '2024', 'age': 20}

# %%
a = 10
b = 2.5
c = True
d = "priya"
e = "123"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# bool

# %%
type(d)
# Out:
# str

# %%
type(e)
# Out:
# str

# %%
a = 10
b = float(a)
print(b)
type(b)
# Out:
# 10.0
# float

# %%
x = 5.8
num = 100
value = "50"

# %%
x = 5.8
z = int(x)
print(z)
type(z)
# Out:
# 5
# int

# %%
num = 100

print("100")
type(num)
# Out:
# 100
# int

# %%
a = "50"
b=(int)

print(b)

type(b)
# Out:
# <class 'int'>
# type

# %%
value = "50"
a = int(value)

print(a)

type(a)
# Out:
# 50
# int

# %%
name = input (" Enter your name : ")
print(name)

# %%
a = 10
b = 20
